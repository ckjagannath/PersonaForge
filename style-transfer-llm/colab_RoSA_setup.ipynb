# %% [markdown]
# Steps to use micromamba to get the desired environment setup with RoSA in Colab and saving .yml to drive for later use

# %%
# !wget -qO- https://micro.mamba.pm/api/micromamba/linux-64/latest | tar -xvj bin/micromamba
# !mv bin/micromamba /usr/local/bin/
# Out:
# bin/micromamba

# %%
# !micromamba create -y -n myenv -c conda-forge python=3.10

# %% [markdown]
# !micromamba run -n myenv command

# %%
# !micromamba run -n myenv pip install git+https://github.com/IST-DASLab/peft-rosa.git

# %%
# !micromamba run -n myenv pip install git+https://github.com/IST-DASLab/spops.git

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !micromamba env export -n myenv > /content/drive/MyDrive/myenv.yml
